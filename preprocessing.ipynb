# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
import matplotlib.pyplot as plt
import random

# %%
#define paths

data_dir = '/analysis/shikhar/abcd_npc/img_dt/' #'/analysis/shikhar/abcd_npc/img_dt/' #or /data/Ritter/abcd_np/
trainy_filename = 'train/train_y.csv'
valy_filename = 'val/val_y.csv'
testy_filename ='test/test_y.csv'
trainx_filename = 'train/volumetrix_data_train.csv'
valx_filename = 'val/volumetrix_data_val.csv'
testx_filename = 'test/volumetrix_data_test.csv'

# %%
#loading datasets

trainy= pd.read_csv(data_dir+trainy_filename, index_col=False)
valy= pd.read_csv(data_dir+valy_filename, index_col=False)
testy= pd.read_csv(data_dir+testy_filename, index_col=False)
trainx =  pd.read_csv(data_dir+trainx_filename, index_col=False)
valx =  pd.read_csv(data_dir+valx_filename, index_col=False)
testx =  pd.read_csv(data_dir+testx_filename, index_col=False)

# %%
#append all

all_data = trainx.append(valx).append(testx).copy()
all_data['sex_bin'] = np.where(all_data['GENDER']=='F', 1, 0)
all_data = all_data.drop(['BTSV01_ID','DATASET_ID','GENDER','SRC_SUBJECT_ID','INTERVIEW_DATE'],\
                         axis=1).copy() ## removing irrelevant columns
trainyValy_moredt = pd.merge(all_data[['SUBJECTKEY','INTERVIEW_AGE','sex_bin','STUDY_COHORT_NAME']], \
                             trainy.append(valy), left_on='SUBJECTKEY', right_on='subject')
print(all_data.STUDY_COHORT_NAME.value_counts())
print(trainy.shape)
print(valy.shape)
# Out:
# ABCD NP Challenge 2019 Training Set      3736
# ABCD NP Challenge 2019 Test Set          3640
# ABCD NP Challenge 2019 Validation Set     415
# Name: STUDY_COHORT_NAME, dtype: int64
# (3739, 2)
# (415, 2)

# %% [markdown]
# #### ^^^ Training set should have been 3739, test should have been 3648 <<< In order to use above we would need imputation
# ##### checked in R> all IDs in volumetrix data have scan data (i.e no new random ID)

# %% [markdown]
# ----
# ### Adding missing subjects (no volumetrix data) and imputing their volumetrix values

# %%
# appending missing Subjects

missing_dict={'test':list(set(testy.subject).difference(set(testx.SUBJECTKEY))),\
         'train':list(set(trainy.subject).difference(set(trainx.SUBJECTKEY)))}

for key, values in missing_dict.items():
    if key=='test':
        studyname = 'ABCD NP Challenge 2019 Test Set'
        for key in values:
            all_data = all_data.append([{'SUBJECTKEY':key, 'STUDY_COHORT_NAME':studyname}], ignore_index=True)
    else:
        studyname = 'ABCD NP Challenge 2019 Training Set'
        for key in values:
            all_data = all_data.append([{'SUBJECTKEY':key, 'STUDY_COHORT_NAME':studyname}], ignore_index=True)
# Out:
# /home/shikhar/.local/lib/python3.6/site-packages/pandas/core/indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
print(all_data['sex_bin'].value_counts())
print(all_data['sex_bin'].isna().value_counts())
# Out:
# 0.0    4085
# 1.0    3706
# Name: sex_bin, dtype: int64
# False    7791
# True       11
# Name: sex_bin, dtype: int64

# %%
#randomly assigning sex to appended subjects (only 11 new subjects)
np.random.seed(seed=234)
all_data['sex_bin'] = all_data['sex_bin'].fillna( \
                pd.Series(np.random.choice(all_data[all_data['sex_bin'].notna()]['sex_bin'], size=len(all_data.index)))\
                                                ) 
print(all_data['sex_bin'].value_counts())
print(all_data['sex_bin'].isna().value_counts())
# Out:
# 0.0    4092
# 1.0    3710
# Name: sex_bin, dtype: int64
# False    7802
# Name: sex_bin, dtype: int64

# %%
#imputing mean for rest of the columns (only 11 new subjects)
all_data = all_data.fillna(all_data.mean()).copy()
print(all_data.STUDY_COHORT_NAME.value_counts())
# Out:
# ABCD NP Challenge 2019 Training Set      3739
# ABCD NP Challenge 2019 Test Set          3648
# ABCD NP Challenge 2019 Validation Set     415
# Name: STUDY_COHORT_NAME, dtype: int64

# %% [markdown]
# ---
# ### Normalizing and checking for correlation

# %%
idv_scaler = MinMaxScaler(feature_range=(0, 1))
idv_scaler.fit(all_data[all_data.columns.difference(['SUBJECTKEY','STUDY_COHORT_NAME','sex_bin'])])
all_data[all_data.columns.difference(['SUBJECTKEY','STUDY_COHORT_NAME','sex_bin'])] = \
    idv_scaler.transform(all_data[all_data.columns.difference(['SUBJECTKEY','STUDY_COHORT_NAME','sex_bin'])])
all_data
# Out:
#             SUBJECTKEY  INTERVIEW_AGE  SRI24PRECENTRALLGM  SRI24PRECENTRALRGM  \
# 0     NDAR_INV47FFMT85       0.730769            0.427935            0.312790
# 1     NDAR_INVGP0KJLU3       0.653846            0.375488            0.484359
# 2     NDAR_INVPMHGZU3M       0.500000            0.448786            0.504869
# 3     NDAR_INVRPYKZRFL       0.384615            0.330454            0.468127
# 4     NDAR_INVB8UX2D6Y       0.500000            0.318695            0.586295
# 5     NDAR_INVXHD5E4MN       0.076923            0.238062            0.302160
# 6     NDAR_INVLGBWLRM4       0.307692            0.152099            0.259396
# 7     NDAR_INVUCGJ1U8F       0.500000            0.295462            0.496603
# 8     NDAR_INVAVR6TURT       0.269231            0.296849            0.446853
# 9     NDAR_INV930295U4       0.384615            0.484346            0.455493
# 10    NDAR_INVH9G32LJW       0.807692            0.287294            0.318615
# 11    NDAR_INV6ZU9NKBV       0.884615            0.407458            0.458383
# 12    NDAR_INV96WYY4C5       0.538462            0.303177            0.505527
# 13    NDAR_INVKLLP08KA       0.346154            0.371053            0.447592
# 14    NDAR_INVFV0JWJ60       0.653846            0.422754            0.447958
# 15    NDAR_INVXHKRJC1C       0.730769            0.417545            0.445879
# 16    NDAR_INVHVXDEAGU       0.807692            0.486391            0.429055
# 17    NDAR_INV2NZV8ELL       0.884615            0.438085            0.427309
# 18    NDAR_INV36DKMERA       0.076923            0.458305            0.403826
# 19    NDAR_INV1ZY3ZR47       0.923077            0.421483            0.519997
# 20    NDAR_INV2V8997BF       0.346154            0.329778            0.413099
# 21    NDAR_INVGALZWY31       0.692308            0.380261            0.314055
# 22    NDAR_INVWZRB4WLL       0.038462            0.304608            0.350116
# 23    NDAR_INV4T2VAM3Y       0.230769            0.300653            0.443500
# 24    NDAR_INVLEXJMGJ6       0.307692            0.285837            0.490100
# 25    NDAR_INVN1VPLV83       0.230769            0.550152            0.511187
# 26    NDAR_INVWE1Z3L3H       0.346154            0.271181            0.766344
# 22                 0.363261            0.438651            0.323132   ...
# 23                 0.421311            0.537741            0.605689   ...
# 24                 0.348331            0.483893            0.337335   ...
# 25                 0.359924            0.209845            0.402212   ...
# 26                 0.224703            0.543607            0.557378   ...
# 27                 0.464674            0.630956            0.406048   ...
# 28                 0.546375            0.451451            0.340738   ...
# 29                 0.292660            0.670995            0.508807   ...
# ...                     ...                 ...                 ...   ...
# 7772               0.476736            0.475723            0.554384   ...
# 7773               0.442399            0.291075            0.295570   ...
# 7774               0.441016            0.392510            0.596614   ...
# 7775               0.241384            0.221250            0.247779   ...
# 7776               0.506926            0.518385            0.499559   ...
# 7777               0.465707            0.450770            0.516235   ...
# 7778               0.526605            0.221906            0.361164   ...
# 7779               0.346062            0.456830            0.783447   ...
# 7780               0.506953            0.532589            0.545286   ...
# 7781               0.493241            0.378499            0.381093   ...
# 7782               0.383906            0.593211            0.471823   ...
# 7783               0.317845            0.433020            0.411846   ...
# 7784               0.548463            0.575645            0.425017   ...
# 7785               0.358586            0.657523            0.535786   ...
# 7786               0.425152            0.455115            0.422992   ...
# 7787               0.358618            0.429406            0.268590   ...
# 7788               0.463654            0.562459            0.427175   ...
# 7789               0.356498            0.382702            0.504600   ...
# 7790               0.357513            0.660430            0.905260   ...
# 7791               0.422083            0.495728            0.477786   ...
# 7792               0.422083            0.495728            0.477786   ...
# 7793               0.422083            0.495728            0.477786   ...
# 7794               0.422083            0.495728            0.477786   ...
# 7795               0.422083            0.495728            0.477786   ...
# 7796               0.422083            0.495728            0.477786   ...
# 7797               0.422083            0.495728            0.477786   ...
# 7798               0.422083            0.495728            0.477786   ...
# 7799               0.422083            0.495728            0.477786   ...
# 7800               0.422083            0.495728            0.477786   ...
# 7801               0.422083            0.495728            0.477786   ...
#
#       SRI24CORPUSCALLOSUMWM  SRI24WM400WM400LWM  SRI24WM400WM400RWM  \
# 0                  0.442683            0.573540            0.551201
# 1                  0.394940            0.375327            0.286871
# 2                  0.644641            0.692629            0.728605
# 3                  0.666578            0.566847            0.543932
# 4                  0.314876            0.429555            0.456135
# 5                  0.618360            0.484964            0.473223
# 6                  0.534445            0.678909            0.670324
# 7                  0.428261            0.736634            0.740361
# 8                  0.332979            0.422191            0.421817
# 9                  0.547942            0.554798            0.520046
# 10                 0.572170            0.559498            0.521792
# 11                 0.533105            0.554562            0.579380
# 12                 0.468887            0.349116            0.396427
# 13                 0.446135            0.468842            0.471799
# 14                 0.535768            0.566450            0.544676
# 15                 0.394388            0.385318            0.385589
# 16                 0.708282            0.638892            0.653237
# 17                 0.498867            0.421517            0.334561
# 18                 0.493853            0.474632            0.414680
# 19                 0.272163            0.383564            0.401471
# 20                 0.446610            0.362577            0.343863
# 21                 0.587168            0.492999            0.459899
# 22                 0.440002            0.393117            0.405820
# 23                 0.395135            0.305819            0.292676
# 24                 0.445847            0.413422            0.442800
# 25                 0.437890            0.580788            0.559834
# 26                 0.308717            0.474767            0.448564
# 27                 0.420287            0.434701            0.432973
# 28                 0.524002            0.542648            0.460269
# 29                 0.211407            0.247004            0.172729
# ...                     ...                 ...                 ...
# 7772               0.565035            0.496402            0.491997
# 7773               0.547322            0.488577            0.478280
# 7774               0.757382            0.680535            0.681360
# 7775               0.538101            0.503766            0.514647
# 7776               0.345907            0.354179            0.394151
# 7777               0.402863            0.351342            0.354044
# 7778               0.432622            0.386394            0.316957
# 7779               0.593140            0.597079            0.639893
# 7780               0.593793            0.503830            0.485775
# 7781               0.534241            0.558774            0.590063
# 7782               0.527650            0.552681            0.531376
# 7783               0.255002            0.316901            0.328848
# 7784               0.533164            0.519724            0.535291
# 7785               0.361898            0.426827            0.470677
# 7786               0.335600            0.499981            0.503137
# 7787               0.563898            0.613929            0.609418
# 7788               0.542199            0.614974            0.635759
# 7789               0.606874            0.474932            0.468803
# 7790               0.549910            0.455808            0.501140
# 7791               0.487938            0.483249            0.474437
# 7792               0.487938            0.483249            0.474437
# 7793               0.487938            0.483249            0.474437
# 7794               0.487938            0.483249            0.474437
# 7795               0.487938            0.483249            0.474437
# 7796               0.487938            0.483249            0.474437
# 7797               0.487938            0.483249            0.474437
# 7798               0.487938            0.483249            0.474437
# 7799               0.487938            0.483249            0.474437
# 7800               0.487938            0.483249            0.474437
# 7801               0.487938            0.483249            0.474437
#
#       SRI24VTLSLATERALVTLLCSF  SRI24VTLSLATERALVTLRCSF  SRI24VTLSTHIRDVTLLCSF  \
# 0                    0.113070                 0.078897               0.219352
# 1                    0.072311                 0.042373               0.146441
# 2                    0.210519                 0.047408               0.296774
# 3                    0.025747                 0.005786               0.096684
# 4                    0.107885                 0.038739               0.215837
# 5                    0.060954                 0.030514               0.293549
# 6                    0.086915                 0.103254               0.267514
# 7                    0.069557                 0.035983               0.456799
# 8                    0.091726                 0.053141               0.248261
# 9                    0.042634                 0.032454               0.199797
# 10                   0.270071                 0.111025               0.227296
# 11                   0.157285                 0.036592               0.261736
# 12                   0.263271                 0.092807               0.226721
# 13                   0.076935                 0.086446               0.195046
# 14                   0.089749                 0.068187               0.101506
# 15                   0.175796                 0.065220               0.274355
# 16                   0.204446                 0.084187               0.182925
# 17                   0.070910                 0.061328               0.172547
# 18                   0.515941                 0.229177               0.080296
# 19                   0.040662                 0.031455               0.184668
# 20                   0.153700                 0.121124               0.476868
# 21                   0.113989                 0.037224               0.307625
# 22                   0.098377                 0.048212               0.246205
# 23                   0.163847                 0.059139               0.230510
# 24                   0.049052                 0.035011               0.187379
# 25                   0.131064                 0.055513               0.226010
# 26                   0.131115                 0.030746               0.174606
# 27                   0.122484                 0.096349               0.291112
# 28                   0.132507                 0.075625               0.182011
# 29                   0.172172                 0.128926               0.337500
# ...                       ...                      ...                    ...
# 7772                 0.251486                 0.070202               0.178024
# 7773                 0.068451                 0.048812               0.187537
# 7774                 0.063167                 0.042163               0.096204
# 7775                 0.199528                 0.112041               0.262994
# 7776                 0.151511                 0.076195               0.285604
# 7777                 0.070535                 0.077345               0.303723
# 7800               0.254493                     0.283550
# 7801               0.254493                     0.283550
#
#                         STUDY_COHORT_NAME  sex_bin
# 0     ABCD NP Challenge 2019 Training Set      1.0
# 1     ABCD NP Challenge 2019 Training Set      0.0
# 2     ABCD NP Challenge 2019 Training Set      1.0
# 3     ABCD NP Challenge 2019 Training Set      1.0
# 4     ABCD NP Challenge 2019 Training Set      1.0
# 5     ABCD NP Challenge 2019 Training Set      0.0
# 6     ABCD NP Challenge 2019 Training Set      1.0
# 7     ABCD NP Challenge 2019 Training Set      1.0
# 8     ABCD NP Challenge 2019 Training Set      0.0
# 9     ABCD NP Challenge 2019 Training Set      0.0
# 10    ABCD NP Challenge 2019 Training Set      1.0
# 11    ABCD NP Challenge 2019 Training Set      0.0
# 12    ABCD NP Challenge 2019 Training Set      1.0
# 13    ABCD NP Challenge 2019 Training Set      0.0
# 14    ABCD NP Challenge 2019 Training Set      1.0
# 15    ABCD NP Challenge 2019 Training Set      0.0
# 16    ABCD NP Challenge 2019 Training Set      1.0
# 17    ABCD NP Challenge 2019 Training Set      0.0
# 18    ABCD NP Challenge 2019 Training Set      0.0
# 19    ABCD NP Challenge 2019 Training Set      1.0
# 20    ABCD NP Challenge 2019 Training Set      0.0
# 21    ABCD NP Challenge 2019 Training Set      1.0
# 22    ABCD NP Challenge 2019 Training Set      0.0
# 23    ABCD NP Challenge 2019 Training Set      0.0
# 24    ABCD NP Challenge 2019 Training Set      0.0
# 25    ABCD NP Challenge 2019 Training Set      1.0
# 26    ABCD NP Challenge 2019 Training Set      0.0
# 27    ABCD NP Challenge 2019 Training Set      0.0
# 28    ABCD NP Challenge 2019 Training Set      1.0
# 29    ABCD NP Challenge 2019 Training Set      0.0
# ...                                   ...      ...
# 7772      ABCD NP Challenge 2019 Test Set      0.0
# 7773      ABCD NP Challenge 2019 Test Set      0.0
# 7774      ABCD NP Challenge 2019 Test Set      0.0
# 7775      ABCD NP Challenge 2019 Test Set      0.0
# 7776      ABCD NP Challenge 2019 Test Set      1.0
# 7777      ABCD NP Challenge 2019 Test Set      1.0
# 7778      ABCD NP Challenge 2019 Test Set      0.0
# 7779      ABCD NP Challenge 2019 Test Set      1.0
# 7780      ABCD NP Challenge 2019 Test Set      1.0
# 7781      ABCD NP Challenge 2019 Test Set      1.0
# 7782      ABCD NP Challenge 2019 Test Set      0.0
# 7783      ABCD NP Challenge 2019 Test Set      1.0
# 7784      ABCD NP Challenge 2019 Test Set      1.0
# 7785      ABCD NP Challenge 2019 Test Set      0.0
# 7786      ABCD NP Challenge 2019 Test Set      1.0
# 7787      ABCD NP Challenge 2019 Test Set      0.0
# 7788      ABCD NP Challenge 2019 Test Set      0.0
# 7789      ABCD NP Challenge 2019 Test Set      0.0
# 7790      ABCD NP Challenge 2019 Test Set      1.0
# 7791      ABCD NP Challenge 2019 Test Set      1.0
# 7792      ABCD NP Challenge 2019 Test Set      1.0
# 7793      ABCD NP Challenge 2019 Test Set      0.0
# 7794      ABCD NP Challenge 2019 Test Set      0.0
# 7795      ABCD NP Challenge 2019 Test Set      0.0
# 7796      ABCD NP Challenge 2019 Test Set      0.0
# 7797      ABCD NP Challenge 2019 Test Set      0.0
# 7798      ABCD NP Challenge 2019 Test Set      1.0
# 7799  ABCD NP Challenge 2019 Training Set      0.0
# 7800  ABCD NP Challenge 2019 Training Set      0.0
# 7801  ABCD NP Challenge 2019 Training Set      1.0
#
# [7802 rows x 126 columns]

# %%
# Create correlation matrix
corr_matrix = all_data.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
# Find index of feature columns with correlation greater than 0.95
to_drop_dueTOhighCor = [column for column in upper.columns if any(upper[column] > 0.95)]
to_drop_dueTOhighCor
# Out:
# ['SRI24THALAMUSRGM', 'SRI24CBLMHEMIWHTRWM', 'SRI24WM400WM400RWM']

# %%
all_data = all_data[all_data.columns.difference(to_drop_dueTOhighCor)].copy()

# checked for 0 variance columns, there are none.

# %% [markdown]
# ___

# %% [markdown]
# ### Splitting in train (80%), validation_internal (5%), validation_forEnsemble (15%) with strata on sex, IQ and age

# %%
# extracting columns on which I need to create strata 


trainyValy_moredt['age_bin']=pd.qcut(trainyValy_moredt['INTERVIEW_AGE'], 5, labels=list(range(0,5)))
trainyValy_moredt['Score_bin']=pd.qcut(trainyValy_moredt['residual_fluid_intelligence_score'], 10,\
                                       labels=list(range(0,10)))
trainyValy_moredt.STUDY_COHORT_NAME.value_counts()
# Out:
# ABCD NP Challenge 2019 Training Set      3736
# ABCD NP Challenge 2019 Validation Set     415
# Name: STUDY_COHORT_NAME, dtype: int64

# %%
val = trainyValy_moredt[trainyValy_moredt['STUDY_COHORT_NAME']=='ABCD NP Challenge 2019 Validation Set']
trainy_moredt = trainyValy_moredt[trainyValy_moredt['STUDY_COHORT_NAME']=='ABCD NP Challenge 2019 Training Set']
print(val.shape)
print(trainy_moredt.shape)
# Out:
# (415, 8)
# (3736, 8)

# %%
# splitting training into 80-20 and the 20 further into 75-25 (75 for ensemble and 25 our internal validation)

train, vals = train_test_split(trainy_moredt, \
                                       test_size=0.20, \
                                       random_state=243,\
                                       stratify=trainy_moredt[['Score_bin', 'sex_bin','age_bin']])
val_ForEnsemble, val_internal = train_test_split(vals, \
                                       test_size=0.25, \
                                       random_state=243,\
                                       stratify=vals[['Score_bin', 'sex_bin','age_bin']])

# %%
print("train shape >",train.shape)
print("val_ForEnsemble shape >",val_ForEnsemble.shape)
print("val_internal shape >",val_internal.shape)

print(train.Score_bin.value_counts())
print(val_ForEnsemble.Score_bin.value_counts())
print(val_internal.Score_bin.value_counts())
# Out:
# train shape > (2988, 8)
# val_ForEnsemble shape > (561, 8)
# val_internal shape > (187, 8)
# 8    310
# 9    307
# 0    304
# 2    301
# 6    300
# 3    300
# 7    299
# 1    292
# 5    288
# 4    287
# Name: Score_bin, dtype: int64
# 8    59
# 6    57
# 2    57
# 1    57
# 9    56
# 7    56
# 3    56
# 0    56
# 4    54
# 5    53
# Name: Score_bin, dtype: int64
# 9    21
# 5    21
# 3    19
# 0    19
# 8    18
# 7    18
# 6    18
# 4    18
# 1    18
# 2    17
# Name: Score_bin, dtype: int64

# %%
# adding category column
train['sample'] = 'train'
val_ForEnsemble['sample'] = 'val_forEnsemble'
val_internal['sample'] = 'val_internal'
val['sample'] = 'val'
# Out:
# /home/shikhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/shikhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/shikhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/shikhar/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
allY_withsegments = train.append(val_ForEnsemble).append(val_internal).append(val).copy()
allY_withsegments['sample'].value_counts()
# Out:
# train              2988
# val_forEnsemble     561
# val                 415
# val_internal        187
# Name: sample, dtype: int64

# %%
allY_withsegments.to_csv(data_dir+'allY_withsegments.csv', sep=',',index=False)

# %%
all_data = pd.merge(all_data, allY_withsegments[['residual_fluid_intelligence_score','SUBJECTKEY','sample']], on='SUBJECTKEY',how='left')

# %%
all_data['sample'].isna().value_counts()
# Out:
# False    4151
# True     3651
# Name: sample, dtype: int64

# %%
all_data.to_csv(data_dir+'all_volumetrix_processed.csv', sep=',',index=False)

# %%
# Out:
#       INTERVIEW_AGE  SRI24AMYGDALALGM  SRI24AMYGDALARGM  SRI24ANGULARLGM  \
# 0          0.730769          0.414616          0.498913         0.408479
# 1          0.653846          0.503110          0.495210         0.403832
# 2          0.500000          0.362114          0.445087         0.258911
# 3          0.384615          0.354227          0.495866         0.564634
# 4          0.500000          0.504922          0.536298         0.415827
# 5          0.076923          0.548186          0.623860         0.366376
# 6          0.307692          0.282067          0.379114         0.295948
# 7          0.500000          0.574076          0.609198         0.375601
# 8          0.269231          0.350792          0.536245         0.365410
# 9          0.384615          0.409298          0.545981         0.261631
# 10         0.807692          0.274744          0.468093         0.465260
# 11         0.884615          0.371269          0.507542         0.347618
# 12         0.538462          0.278778          0.511156         0.564611
# 13         0.346154          0.413953          0.375305         0.299900
# 14         0.653846          0.381466          0.425172         0.472070
# 15         0.730769          0.511661          0.573842         0.216586
# 16         0.807692          0.471962          0.529441         0.502023
# 17         0.884615          0.516718          0.591852         0.353390
# 18         0.076923          0.573709          0.438221         0.723013
# 19         0.923077          0.295884          0.489213         0.344857
# 20         0.346154          0.369801          0.439949         0.268466
# 21         0.692308          0.478156          0.572894         0.434483
# 22         0.038462          0.393760          0.448267         0.522589
# 23         0.230769          0.228389          0.413407         0.481274
# 24         0.307692          0.482964          0.757700         0.434417
# 25         0.230769          0.373839          0.482445         0.364401
# 26         0.346154          0.540891          0.621149         0.664416
# 27         0.461538          0.223142          0.259439         0.459847
# 28         0.923077          0.597763          0.730264         0.126649
# 29         0.615385          0.553125          0.505265         0.448497
# ...             ...               ...               ...              ...
# 7772       0.923077          0.480880          0.613627         0.228871
# 7773       0.192308          0.505739          0.495990         0.273953
# 7774       0.961538          0.352296          0.359988         0.256093
# 7775       0.038462          0.558123          0.577288         0.523118
# 7776       0.076923          0.387744          0.584499         0.455310
# 7777       0.923077          0.351657          0.371930         0.472902
# 7778       0.230769          0.885984          0.388310         0.674199
# 7779       0.461538          0.505704          0.584172         0.344455
# 7792         0.440566             0.392173       ...
# 7793         0.440566             0.392173       ...
# 7794         0.440566             0.392173       ...
# 7795         0.440566             0.392173       ...
# 7796         0.440566             0.392173       ...
# 7797         0.440566             0.392173       ...
# 7798         0.440566             0.392173       ...
# 7799         0.440566             0.392173       ...
# 7800         0.440566             0.392173       ...
# 7801         0.440566             0.392173       ...
#
#       SRI24VTLSLATERALVTLLCSF  SRI24VTLSLATERALVTLRCSF  SRI24VTLSTHIRDVTLLCSF  \
# 0                    0.113070                 0.078897               0.219352
# 1                    0.072311                 0.042373               0.146441
# 2                    0.210519                 0.047408               0.296774
# 3                    0.025747                 0.005786               0.096684
# 4                    0.107885                 0.038739               0.215837
# 5                    0.060954                 0.030514               0.293549
# 6                    0.086915                 0.103254               0.267514
# 7                    0.069557                 0.035983               0.456799
# 8                    0.091726                 0.053141               0.248261
# 9                    0.042634                 0.032454               0.199797
# 10                   0.270071                 0.111025               0.227296
# 11                   0.157285                 0.036592               0.261736
# 12                   0.263271                 0.092807               0.226721
# 13                   0.076935                 0.086446               0.195046
# 14                   0.089749                 0.068187               0.101506
# 15                   0.175796                 0.065220               0.274355
# 16                   0.204446                 0.084187               0.182925
# 17                   0.070910                 0.061328               0.172547
# 18                   0.515941                 0.229177               0.080296
# 19                   0.040662                 0.031455               0.184668
# 20                   0.153700                 0.121124               0.476868
# 21                   0.113989                 0.037224               0.307625
# 22                   0.098377                 0.048212               0.246205
# 23                   0.163847                 0.059139               0.230510
# 24                   0.049052                 0.035011               0.187379
# 25                   0.131064                 0.055513               0.226010
# 26                   0.131115                 0.030746               0.174606
# 27                   0.122484                 0.096349               0.291112
# 28                   0.132507                 0.075625               0.182011
# 29                   0.172172                 0.128926               0.337500
# ...                       ...                      ...                    ...
# 7772                 0.251486                 0.070202               0.178024
# 7773                 0.068451                 0.048812               0.187537
# 7774                 0.063167                 0.042163               0.096204
# 7775                 0.199528                 0.112041               0.262994
# 7776                 0.151511                 0.076195               0.285604
# 7777                 0.070535                 0.077345               0.303723
# 7778                 0.099228                 0.031492               0.207818
# 7779                 0.144356                 0.081944               0.362136
# 7780                 0.078166                 0.046096               0.120334
# 7781                 0.050883                 0.028367               0.213598
# 7782                 0.135574                 0.069705               0.319976
# 7783                 0.132949                 0.182357               0.119830
# 7784                 0.096607                 0.055749               0.290811
# 7785                 0.154901                 0.138130               0.142070
# 7786                 0.047538                 0.056127               0.304278
# 7787                 0.020496                 0.019280               0.185403
# 7788                 0.158108                 0.082876               0.237578
# 7789                 0.054781                 0.023169               0.081303
# 7790                 0.115494                 0.098855               0.187131
# 7791                 0.115694                 0.067335               0.247651
# 7792                 0.115694                 0.067335               0.247651
# 7793                 0.115694                 0.067335               0.247651
# 7794                 0.115694                 0.067335               0.247651
# 7795                 0.115694                 0.067335               0.247651
# 7796                 0.115694                 0.067335               0.247651
# 7797                 0.115694                 0.067335               0.247651
# 7798                 0.115694                 0.067335               0.247651
# 7799                 0.115694                 0.067335               0.247651
# 7800                 0.115694                 0.067335               0.247651
# 7801                 0.115694                 0.067335               0.247651
#
#       SRI24VTLSTHIRDVTLRCSF  SRI24WM400WM400LWM  \
# 0                  0.268849            0.573540
# 1                  0.109464            0.375327
# 2                  0.326918            0.692629
# 3                  0.154030            0.566847
# 4                  0.247668            0.429555
# 5                  0.253250            0.484964
# 6                  0.265772            0.678909
# 7                  0.351558            0.736634
# 8                  0.210657            0.422191
# 9                  0.150750            0.554798
# 10                 0.276315            0.559498
# 11                 0.288822            0.554562
# 12                 0.235570            0.349116
# 13                 0.226984            0.468842
# 14                 0.129567            0.566450
# 15                 0.249186            0.385318
# 16                 0.224165            0.638892
# 17                 0.148652            0.421517
# 18                 0.076970            0.474632
# 19                 0.176629            0.383564
# 20                 0.489494            0.362577
# 21                 0.228893            0.492999
# 22                 0.260405            0.393117
# 23                 0.265314            0.305819
# 24                 0.213258            0.413422
# 25                 0.278703            0.580788
# 26                 0.135558            0.474767
# 27                 0.262579            0.434701
# 28                 0.183758            0.542648
# 29                 0.317619            0.247004
# ...                     ...                 ...
# 7772               0.219014            0.496402
# 7773               0.201112            0.488577
# 7774               0.191143            0.680535
# 7775               0.262379            0.503766
# 7776               0.250011            0.354179
# 7777               0.319346            0.351342
# 7778               0.296181            0.386394
# 7779               0.291240            0.597079
# 7780               0.084175            0.503830
# 7781               0.209555            0.558774
# 7782               0.452382            0.552681
# 7783               0.104344            0.316901
# 7784               0.349281            0.519724
# 7785               0.128153            0.426827
# 7786               0.280542            0.499981
# 7787               0.195207            0.613929
# 7788               0.351735            0.614974
# 7789               0.129486            0.474932
# 7790               0.265082            0.455808
# 7791               0.254493            0.483249
# 7792               0.254493            0.483249
# 7793               0.254493            0.483249
# 7794               0.254493            0.483249
# 7795               0.254493            0.483249
# 7796               0.254493            0.483249
# 7797               0.254493            0.483249
# 7798               0.254493            0.483249
# 7799               0.254493            0.483249
# 7800               0.254493            0.483249
# 7801               0.254493            0.483249
#
#                         STUDY_COHORT_NAME        SUBJECTKEY  sex_bin  \
# 0     ABCD NP Challenge 2019 Training Set  NDAR_INV47FFMT85      1.0
# 1     ABCD NP Challenge 2019 Training Set  NDAR_INVGP0KJLU3      0.0
# 2     ABCD NP Challenge 2019 Training Set  NDAR_INVPMHGZU3M      1.0
# 3     ABCD NP Challenge 2019 Training Set  NDAR_INVRPYKZRFL      1.0
# 4     ABCD NP Challenge 2019 Training Set  NDAR_INVB8UX2D6Y      1.0
# 5     ABCD NP Challenge 2019 Training Set  NDAR_INVXHD5E4MN      0.0
# 6     ABCD NP Challenge 2019 Training Set  NDAR_INVLGBWLRM4      1.0
# 7     ABCD NP Challenge 2019 Training Set  NDAR_INVUCGJ1U8F      1.0
# 8     ABCD NP Challenge 2019 Training Set  NDAR_INVAVR6TURT      0.0
# 9     ABCD NP Challenge 2019 Training Set  NDAR_INV930295U4      0.0
# 10    ABCD NP Challenge 2019 Training Set  NDAR_INVH9G32LJW      1.0
# 11    ABCD NP Challenge 2019 Training Set  NDAR_INV6ZU9NKBV      0.0
# 12    ABCD NP Challenge 2019 Training Set  NDAR_INV96WYY4C5      1.0
# 13    ABCD NP Challenge 2019 Training Set  NDAR_INVKLLP08KA      0.0
# 14    ABCD NP Challenge 2019 Training Set  NDAR_INVFV0JWJ60      1.0
# 15    ABCD NP Challenge 2019 Training Set  NDAR_INVXHKRJC1C      0.0
# 16    ABCD NP Challenge 2019 Training Set  NDAR_INVHVXDEAGU      1.0
# 17    ABCD NP Challenge 2019 Training Set  NDAR_INV2NZV8ELL      0.0
# 18    ABCD NP Challenge 2019 Training Set  NDAR_INV36DKMERA      0.0
# 19    ABCD NP Challenge 2019 Training Set  NDAR_INV1ZY3ZR47      1.0
# 20    ABCD NP Challenge 2019 Training Set  NDAR_INV2V8997BF      0.0
# 21    ABCD NP Challenge 2019 Training Set  NDAR_INVGALZWY31      1.0
# 22    ABCD NP Challenge 2019 Training Set  NDAR_INVWZRB4WLL      0.0
# 23    ABCD NP Challenge 2019 Training Set  NDAR_INV4T2VAM3Y      0.0
# 24    ABCD NP Challenge 2019 Training Set  NDAR_INVLEXJMGJ6      0.0
# 25    ABCD NP Challenge 2019 Training Set  NDAR_INVN1VPLV83      1.0
# 26    ABCD NP Challenge 2019 Training Set  NDAR_INVWE1Z3L3H      0.0
# 27    ABCD NP Challenge 2019 Training Set  NDAR_INVPFC26GTC      0.0
# 28    ABCD NP Challenge 2019 Training Set  NDAR_INV5F2R3TL8      1.0
# 29    ABCD NP Challenge 2019 Training Set  NDAR_INVVZR097LZ      0.0
# ...                                   ...               ...      ...
# 7772      ABCD NP Challenge 2019 Test Set  NDAR_INVM889LV1R      0.0
# 7773      ABCD NP Challenge 2019 Test Set  NDAR_INV4BRVTNUE      0.0
# 7774      ABCD NP Challenge 2019 Test Set  NDAR_INV7MCB12JE      0.0
# 7775      ABCD NP Challenge 2019 Test Set  NDAR_INVJ5B6E6MK      0.0
# 7776      ABCD NP Challenge 2019 Test Set  NDAR_INVG5M25E6R      1.0
# 7777      ABCD NP Challenge 2019 Test Set  NDAR_INVHYH97A58      1.0
# 7778      ABCD NP Challenge 2019 Test Set  NDAR_INVRREA9RBW      0.0
# 7779      ABCD NP Challenge 2019 Test Set  NDAR_INV4L1WDFJ7      1.0
# 7780      ABCD NP Challenge 2019 Test Set  NDAR_INVP3LDF3U5      1.0
# 7781      ABCD NP Challenge 2019 Test Set  NDAR_INV528FZWXG      1.0
# 7782      ABCD NP Challenge 2019 Test Set  NDAR_INV5G3DP835      0.0
# 7783      ABCD NP Challenge 2019 Test Set  NDAR_INVR9MG0HJ4      1.0
# 7784      ABCD NP Challenge 2019 Test Set  NDAR_INVM70F0J7W      1.0
# 7785      ABCD NP Challenge 2019 Test Set  NDAR_INV0YLLNXRL      0.0
# 7786      ABCD NP Challenge 2019 Test Set  NDAR_INV02JXJUZG      1.0
# 7787      ABCD NP Challenge 2019 Test Set  NDAR_INVYJ4PHV0Y      0.0
# 7788      ABCD NP Challenge 2019 Test Set  NDAR_INV7GYDJXB0      0.0
# 7789      ABCD NP Challenge 2019 Test Set  NDAR_INV0JRNB4U4      0.0
# 7790      ABCD NP Challenge 2019 Test Set  NDAR_INV09AEBLZH      1.0
# 7791      ABCD NP Challenge 2019 Test Set  NDAR_INV00LH735Y      1.0
# 7792      ABCD NP Challenge 2019 Test Set  NDAR_INVGEHCD5AD      1.0
# 7793      ABCD NP Challenge 2019 Test Set  NDAR_INVGLTMA4LA      0.0
# 7794      ABCD NP Challenge 2019 Test Set  NDAR_INVGKT12ZAH      0.0
# 7795      ABCD NP Challenge 2019 Test Set  NDAR_INVGD6JWJWD      0.0
# 7796      ABCD NP Challenge 2019 Test Set  NDAR_INV005V6D2C      0.0
# 7797      ABCD NP Challenge 2019 Test Set  NDAR_INVGFRL1TJF      0.0
# 7798      ABCD NP Challenge 2019 Test Set  NDAR_INVGR9UK9P6      1.0
# 7799  ABCD NP Challenge 2019 Training Set  NDAR_INVMAEVPZJ0      0.0
# 7800  ABCD NP Challenge 2019 Training Set  NDAR_INVZJB6P8ZB      0.0
# 7801  ABCD NP Challenge 2019 Training Set  NDAR_INVE0KZKF5V      1.0
#
#       residual_fluid_intelligence_score           sample
# 0                             18.617968     val_internal
# 1                              3.453365            train
# 2                              0.632251            train
# 3                              1.488461            train
# 4                              1.774360     val_internal
# 5                              6.180170  val_forEnsemble
# 6                             11.878714            train
# 7                              1.796625            train
# 8                              2.199330            train
# 9                              6.921028            train
# 10                            -6.653295            train
# 11                           -21.156418            train
# 12                           -14.410722            train
# 13                            -6.019978  val_forEnsemble
# 14                            -1.560887            train
# 15                            -4.561558            train
# 16                            11.730425  val_forEnsemble
# 17                            -5.045972            train
# 18                             0.425788     val_internal
# 19                             3.959371            train
# 20                             6.179221  val_forEnsemble
# 21                           -14.777561            train
# 22                             1.806804            train
# 23                            23.715627            train
# 24                             9.473004            train
# 25                             2.167058            train
# 26                             2.560428            train
# 27                             6.548895     val_internal
# 28                            15.703430            train
# 29                            15.377168            train
# ...                                 ...              ...
# 7772                                NaN              NaN
# 7773                                NaN              NaN
# 7774                                NaN              NaN
# 7775                                NaN              NaN
# 7776                                NaN              NaN
# 7777                                NaN              NaN
# 7778                                NaN              NaN
# 7779                                NaN              NaN
# 7780                                NaN              NaN
# 7781                                NaN              NaN
# 7782                                NaN              NaN
# 7783                                NaN              NaN
# 7784                                NaN              NaN
# 7785                                NaN              NaN
# 7786                                NaN              NaN
# 7787                                NaN              NaN
# 7788                                NaN              NaN
# 7789                                NaN              NaN
# 7790                                NaN              NaN
# 7791                                NaN              NaN
# 7792                                NaN              NaN
# 7793                                NaN              NaN
# 7794                                NaN              NaN
# 7795                                NaN              NaN
# 7796                                NaN              NaN
# 7797                                NaN              NaN
# 7798                                NaN              NaN
# 7799                                NaN              NaN
# 7800                                NaN              NaN
# 7801                                NaN              NaN
#
# [7802 rows x 125 columns]
